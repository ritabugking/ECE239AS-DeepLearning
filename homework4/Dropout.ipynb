# %% [markdown]
# # Dropout
#
# In this notebook, you will implement dropout.  Then we will ask you to train a network with batchnorm and dropout, and acheive over 60% accuracy on CIFAR-10.
#
# CS231n has built a solid API for building these modular frameworks and training them, and we will use their very well implemented framework as opposed to "reinventing the wheel."  This includes using their Solver, various utility functions, and their layer structure.  This also includes nndl.fc_net, nndl.layers, and nndl.layer_utils.  As in prior assignments, we thank Serena Yeung & Justin Johnson for permission to use code written for the CS 231n class (cs231n.stanford.edu).

# %%
## Import and setups

import time
import numpy as np
import matplotlib.pyplot as plt
from nndl.fc_net import *
from nndl.layers import *
from data_utils import get_CIFAR10_data
from gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from solver import Solver

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %%
# Load the (preprocessed) CIFAR10 data.

data = get_CIFAR10_data()
for k in data.keys():
  print('{}: {} '.format(k, data[k].shape))
# Out:
# X_train: (49000, 3, 32, 32)
# y_train: (49000,)
# X_val: (1000, 3, 32, 32)
# y_val: (1000,)
# X_test: (1000, 3, 32, 32)
# y_test: (1000,)

# %% [markdown]
# ## Dropout forward pass
#
# Implement the training and test time dropout forward pass, `dropout_forward`, in `nndl/layers.py`. After that, test your implementation by running the following cell.

# %%
x = np.random.randn(500, 500) + 10

for p in [0.3, 0.6, 0.75]:
  out, _ = dropout_forward(x, {'mode': 'train', 'p': p})
  out_test, _ = dropout_forward(x, {'mode': 'test', 'p': p})

  print('Running tests with p = ', p)
  print('Mean of input: ', x.mean())
  print('Mean of train-time output: ', out.mean())
  print('Mean of test-time output: ', out_test.mean())
  print('Fraction of train-time output set to zero: ', (out == 0).mean())
  print('Fraction of test-time output set to zero: ', (out_test == 0).mean())
# Out:
# Running tests with p =  0.3
# Mean of input:  9.999598931531304
# Mean of train-time output:  23.353408690633703
# Mean of test-time output:  9.999598931531304
# Fraction of train-time output set to zero:  0.299392
# Fraction of test-time output set to zero:  0.0
# Running tests with p =  0.6
# Mean of input:  9.999598931531304
# Mean of train-time output:  6.700569389352877
# Mean of test-time output:  9.999598931531304
# Fraction of train-time output set to zero:  0.597924
# Fraction of test-time output set to zero:  0.0
# Running tests with p =  0.75
# Mean of input:  9.999598931531304
# Mean of train-time output:  3.338608552646527
# Mean of test-time output:  9.999598931531304
# Fraction of train-time output set to zero:  0.749572
# Fraction of test-time output set to zero:  0.0

# %% [markdown]
# ## Dropout backward pass
#
# Implement the backward pass, `dropout_backward`, in `nndl/layers.py`.  After that, test your gradients by running the following cell:

# %%
x = np.random.randn(10, 10) + 10
dout = np.random.randn(*x.shape)

dropout_param = {'mode': 'train', 'p': 0.8, 'seed': 123}
out, cache = dropout_forward(x, dropout_param)
dx = dropout_backward(dout, cache)
dx_num = eval_numerical_gradient_array(lambda xx: dropout_forward(xx, dropout_param)[0], x, dout)

print('dx relative error: ', rel_error(dx, dx_num))
# Out:
# dx relative error:  5.445597707443854e-11

# %% [markdown]
# ## Implement a fully connected neural network with dropout layers
#
# Modify the `FullyConnectedNet()` class in `nndl/fc_net.py` to incorporate dropout.  A dropout layer should be incorporated after every ReLU layer.  Concretely, there shouldn't be a dropout at the output layer since there is no ReLU at the output layer. You will need to modify the class in the following areas:
#
# (1) In the forward pass, you will need to incorporate a dropout layer after every relu layer.
#
# (2) In the backward pass, you will need to incorporate a dropout backward pass layer.
#
# Check your implementation by running the following code.  Our W1 gradient relative error is on the order of 1e-6 (the largest of all the relative errors).

# %%
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for dropout in [0, 0.25, 0.5]:
  print('Running check with dropout = ', dropout)
  model = FullyConnectedNet([H1, H2], input_dim=D, num_classes=C,
                            weight_scale=5e-2, dtype=np.float64,
                            dropout=dropout, seed=123)

  loss, grads = model.loss(X, y)
  print('Initial loss: ', loss)

  for name in sorted(grads):
    f = lambda _: model.loss(X, y)[0]
    grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
    print('{} relative error: {}'.format(name, rel_error(grad_num, grads[name])))
  print('\n')
# Out:
# Running check with dropout =  0
# Initial loss:  2.3051948273987857
# W1 relative error: 2.5272575351926774e-07
# W2 relative error: 1.5034484932141387e-05
# W3 relative error: 2.753446846744471e-07
# b1 relative error: 2.9369574464090924e-06
# b2 relative error: 5.051339805546953e-08
# b3 relative error: 1.1740467838205477e-10
#
#
# Running check with dropout =  0.25
# Initial loss:  2.3303168285760947
# W1 relative error: 2.3951643655220808e-08
# W2 relative error: 3.323948268286626e-08
# W3 relative error: 3.282306197929691e-09
# b1 relative error: 3.328400715838277e-09
# b2 relative error: 1.2549300833489177e-09
# b3 relative error: 1.6511587529782002e-10
#
#
# Running check with dropout =  0.5
# Initial loss:  2.3035667586595423
# W1 relative error: 1.1401257466398776e-06
# W2 relative error: 1.847669552590918e-07
# W3 relative error: 6.5966196982302395e-09
# b1 relative error: 7.716396145006076e-08
# b2 relative error: 1.1975911504312007e-09
# b3 relative error: 1.4558471033827801e-10

# %% [markdown]
# ## Dropout as a regularizer
#
# In class, we claimed that dropout acts as a regularizer by effectively bagging.  To check this, we will train two small networks, one with dropout and one without dropout.

# %%
# Train two identical nets, one with dropout and one without

num_train = 500
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}
dropout_choices = [0, 0.6]
for dropout in dropout_choices:
  model = FullyConnectedNet([100, 100, 100], dropout=dropout)

  solver = Solver(model, small_data,
                  num_epochs=25, batch_size=100,
                  update_rule='adam',
                  optim_config={
                    'learning_rate': 5e-4,
                  },
                  verbose=True, print_every=100)
  solver.train()
  solvers[dropout] = solver
# Out:
# (Iteration 1 / 125) loss: 2.300804
# (Epoch 0 / 25) train acc: 0.220000; val_acc: 0.168000
# (Epoch 1 / 25) train acc: 0.188000; val_acc: 0.147000
# (Epoch 2 / 25) train acc: 0.266000; val_acc: 0.200000
# (Epoch 3 / 25) train acc: 0.338000; val_acc: 0.262000
# (Epoch 4 / 25) train acc: 0.378000; val_acc: 0.278000
# (Epoch 5 / 25) train acc: 0.428000; val_acc: 0.297000
# (Epoch 6 / 25) train acc: 0.468000; val_acc: 0.323000
# (Epoch 7 / 25) train acc: 0.494000; val_acc: 0.287000
# (Epoch 8 / 25) train acc: 0.566000; val_acc: 0.328000
# (Epoch 9 / 25) train acc: 0.572000; val_acc: 0.322000
# (Epoch 10 / 25) train acc: 0.622000; val_acc: 0.324000
# (Epoch 11 / 25) train acc: 0.670000; val_acc: 0.279000
# (Epoch 12 / 25) train acc: 0.710000; val_acc: 0.338000
# (Epoch 13 / 25) train acc: 0.746000; val_acc: 0.319000
# (Epoch 14 / 25) train acc: 0.792000; val_acc: 0.307000
# (Epoch 15 / 25) train acc: 0.834000; val_acc: 0.297000
# (Epoch 16 / 25) train acc: 0.876000; val_acc: 0.327000
# (Epoch 17 / 25) train acc: 0.886000; val_acc: 0.320000
# (Epoch 18 / 25) train acc: 0.918000; val_acc: 0.314000
# (Epoch 19 / 25) train acc: 0.922000; val_acc: 0.290000
# (Epoch 20 / 25) train acc: 0.944000; val_acc: 0.306000
# (Iteration 101 / 125) loss: 0.156105
# (Epoch 21 / 25) train acc: 0.968000; val_acc: 0.302000
# (Epoch 22 / 25) train acc: 0.978000; val_acc: 0.302000
# (Epoch 23 / 25) train acc: 0.976000; val_acc: 0.289000
# (Epoch 24 / 25) train acc: 0.986000; val_acc: 0.285000
# (Epoch 25 / 25) train acc: 0.978000; val_acc: 0.311000
# (Iteration 1 / 125) loss: 2.301219
# (Epoch 0 / 25) train acc: 0.132000; val_acc: 0.146000
# (Epoch 1 / 25) train acc: 0.122000; val_acc: 0.129000
# (Epoch 2 / 25) train acc: 0.190000; val_acc: 0.171000
# (Epoch 3 / 25) train acc: 0.190000; val_acc: 0.165000
# (Epoch 4 / 25) train acc: 0.186000; val_acc: 0.147000
# (Epoch 5 / 25) train acc: 0.206000; val_acc: 0.195000
# (Epoch 6 / 25) train acc: 0.240000; val_acc: 0.195000
# (Epoch 7 / 25) train acc: 0.234000; val_acc: 0.176000
# (Epoch 8 / 25) train acc: 0.264000; val_acc: 0.205000
# (Epoch 9 / 25) train acc: 0.288000; val_acc: 0.217000
# (Epoch 10 / 25) train acc: 0.306000; val_acc: 0.252000
# (Epoch 11 / 25) train acc: 0.302000; val_acc: 0.257000
# (Epoch 12 / 25) train acc: 0.312000; val_acc: 0.264000
# (Epoch 13 / 25) train acc: 0.300000; val_acc: 0.249000
# (Epoch 14 / 25) train acc: 0.322000; val_acc: 0.264000
# (Epoch 15 / 25) train acc: 0.358000; val_acc: 0.270000
# (Epoch 16 / 25) train acc: 0.360000; val_acc: 0.265000
# (Epoch 17 / 25) train acc: 0.368000; val_acc: 0.282000
# (Epoch 18 / 25) train acc: 0.364000; val_acc: 0.272000
# (Epoch 19 / 25) train acc: 0.350000; val_acc: 0.259000
# (Epoch 20 / 25) train acc: 0.360000; val_acc: 0.268000
# (Iteration 101 / 125) loss: 1.839906
# (Epoch 21 / 25) train acc: 0.380000; val_acc: 0.268000
# (Epoch 22 / 25) train acc: 0.392000; val_acc: 0.270000
# (Epoch 23 / 25) train acc: 0.396000; val_acc: 0.289000
# (Epoch 24 / 25) train acc: 0.424000; val_acc: 0.295000
# (Epoch 25 / 25) train acc: 0.440000; val_acc: 0.288000

# %%
# Plot train and validation accuracies of the two models

train_accs = []
val_accs = []
for dropout in dropout_choices:
  solver = solvers[dropout]
  train_accs.append(solver.train_acc_history[-1])
  val_accs.append(solver.val_acc_history[-1])

plt.subplot(3, 1, 1)
for dropout in dropout_choices:
  plt.plot(solvers[dropout].train_acc_history, 'o', label='%.2f dropout' % dropout)
plt.title('Train accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(ncol=2, loc='lower right')
  
plt.subplot(3, 1, 2)
for dropout in dropout_choices:
  plt.plot(solvers[dropout].val_acc_history, 'o', label='%.2f dropout' % dropout)
plt.title('Val accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(ncol=2, loc='lower right')

plt.gcf().set_size_inches(15, 15)
plt.show()

# %% [markdown]
# ## Question
#
# Based off the results of this experiment, is dropout performing regularization?  Explain your answer.

# %% [markdown]
# ## Answer:
# Without dropout, we can see that trianing accuracy ~97% but validation accuracy is 31%. This shows that the model is overfitting. After dropout, training accuracy and Validation accurac ~ 40% and 30%. The training accuracy is comparable to validation accuracy. Therefore, the model is not overfitting which proves that dropout actually is sort of a regularization.

# %% [markdown]
# ## Final part of the assignment
#
# Get over 60% validation accuracy on CIFAR-10 by using the layers you have implemented.  You will be graded according to the following equation:
#
# min(floor((X - 32%)) / 28%, 1)
# where if you get 60% or higher validation accuracy, you get full points.

# %%
# ================================================================ #
# YOUR CODE HERE:
#   Implement a FC-net that achieves at least 60% validation accuracy
#   on CIFAR-10.
# ================================================================ #
learning_rate = 3.1e-4
weight_scale = 2.5e-2 #1e-5
model = FullyConnectedNet([600, 500, 400, 300, 200, 100],
                weight_scale=weight_scale, dtype=np.float64, dropout=0.25, use_batchnorm=True, reg=1e-2)
solver = Solver(model, data,
                print_every=500, num_epochs=50, batch_size=100,
                update_rule='adam',
                optim_config={
                  'learning_rate': learning_rate,
                },
                lr_decay=0.9
         )

solver.train()
# ================================================================ #
# END YOUR CODE HERE
# ================================================================ #
# Out:
# (Iteration 1 / 24500) loss: 10.452489
# (Epoch 0 / 50) train acc: 0.109000; val_acc: 0.110000
# (Epoch 1 / 50) train acc: 0.433000; val_acc: 0.431000
# (Iteration 501 / 24500) loss: 3.915348
# (Epoch 2 / 50) train acc: 0.442000; val_acc: 0.457000
# (Iteration 1001 / 24500) loss: 2.450474
# (Epoch 3 / 50) train acc: 0.481000; val_acc: 0.471000
# (Iteration 1501 / 24500) loss: 2.210188
# (Epoch 4 / 50) train acc: 0.471000; val_acc: 0.475000
# (Iteration 2001 / 24500) loss: 2.023862
# (Epoch 5 / 50) train acc: 0.522000; val_acc: 0.499000
# (Iteration 2501 / 24500) loss: 1.760325
# (Epoch 6 / 50) train acc: 0.526000; val_acc: 0.486000
# (Iteration 3001 / 24500) loss: 1.511257
# (Epoch 7 / 50) train acc: 0.513000; val_acc: 0.501000
# (Iteration 3501 / 24500) loss: 1.610403
# (Epoch 8 / 50) train acc: 0.550000; val_acc: 0.515000
# (Iteration 4001 / 24500) loss: 1.817939
# (Epoch 9 / 50) train acc: 0.548000; val_acc: 0.519000
# (Iteration 4501 / 24500) loss: 1.398761
# (Epoch 10 / 50) train acc: 0.549000; val_acc: 0.524000
# (Iteration 5001 / 24500) loss: 1.667592
# (Epoch 11 / 50) train acc: 0.571000; val_acc: 0.528000
# (Iteration 5501 / 24500) loss: 1.407391
# (Epoch 12 / 50) train acc: 0.587000; val_acc: 0.540000
# (Iteration 6001 / 24500) loss: 1.489597
# (Epoch 13 / 50) train acc: 0.601000; val_acc: 0.556000
# (Iteration 6501 / 24500) loss: 1.500704
# (Epoch 14 / 50) train acc: 0.590000; val_acc: 0.555000
# (Iteration 7001 / 24500) loss: 1.407992
# (Epoch 15 / 50) train acc: 0.631000; val_acc: 0.564000
# (Iteration 7501 / 24500) loss: 1.466608
# (Epoch 16 / 50) train acc: 0.631000; val_acc: 0.563000
# (Iteration 8001 / 24500) loss: 1.501144
# (Epoch 17 / 50) train acc: 0.616000; val_acc: 0.562000
# (Iteration 8501 / 24500) loss: 1.443522
# (Epoch 18 / 50) train acc: 0.630000; val_acc: 0.556000
# (Iteration 9001 / 24500) loss: 1.216849
# (Epoch 19 / 50) train acc: 0.646000; val_acc: 0.592000
# (Iteration 9501 / 24500) loss: 1.299870
# (Epoch 20 / 50) train acc: 0.656000; val_acc: 0.578000
# (Iteration 10001 / 24500) loss: 1.274625
# (Epoch 21 / 50) train acc: 0.703000; val_acc: 0.577000
# (Iteration 10501 / 24500) loss: 1.230604
# (Epoch 22 / 50) train acc: 0.687000; val_acc: 0.574000
# (Iteration 11001 / 24500) loss: 1.272070
# (Epoch 23 / 50) train acc: 0.684000; val_acc: 0.572000
# (Iteration 11501 / 24500) loss: 1.368145
# (Epoch 24 / 50) train acc: 0.710000; val_acc: 0.578000
# (Iteration 12001 / 24500) loss: 1.262961
# (Epoch 25 / 50) train acc: 0.711000; val_acc: 0.580000
# (Iteration 12501 / 24500) loss: 1.117155
# (Epoch 26 / 50) train acc: 0.730000; val_acc: 0.589000
# (Iteration 13001 / 24500) loss: 1.215852
# (Epoch 27 / 50) train acc: 0.758000; val_acc: 0.577000
# (Iteration 13501 / 24500) loss: 1.175670
# (Epoch 28 / 50) train acc: 0.766000; val_acc: 0.585000
# (Iteration 14001 / 24500) loss: 1.238533
# (Epoch 29 / 50) train acc: 0.749000; val_acc: 0.583000
# (Iteration 14501 / 24500) loss: 1.062146
# (Epoch 30 / 50) train acc: 0.788000; val_acc: 0.578000
# (Iteration 15001 / 24500) loss: 1.060189
# (Epoch 31 / 50) train acc: 0.763000; val_acc: 0.588000
# (Iteration 15501 / 24500) loss: 1.182017
# (Epoch 32 / 50) train acc: 0.744000; val_acc: 0.593000
# (Iteration 16001 / 24500) loss: 1.007182
# (Epoch 33 / 50) train acc: 0.773000; val_acc: 0.581000
# (Iteration 16501 / 24500) loss: 1.131237
# (Epoch 34 / 50) train acc: 0.786000; val_acc: 0.586000
# (Iteration 17001 / 24500) loss: 1.068456
# (Epoch 35 / 50) train acc: 0.812000; val_acc: 0.591000
# (Iteration 17501 / 24500) loss: 1.107645
# (Epoch 36 / 50) train acc: 0.788000; val_acc: 0.589000
# (Iteration 18001 / 24500) loss: 1.112802
# (Epoch 37 / 50) train acc: 0.812000; val_acc: 0.595000
# (Iteration 18501 / 24500) loss: 0.888132
# (Epoch 38 / 50) train acc: 0.803000; val_acc: 0.586000
# (Iteration 19001 / 24500) loss: 1.009518
# (Epoch 39 / 50) train acc: 0.807000; val_acc: 0.589000
# (Iteration 19501 / 24500) loss: 0.890550
# (Epoch 40 / 50) train acc: 0.816000; val_acc: 0.604000
# (Iteration 20001 / 24500) loss: 1.200710
# (Epoch 41 / 50) train acc: 0.806000; val_acc: 0.595000
# (Iteration 20501 / 24500) loss: 0.821008
# (Epoch 42 / 50) train acc: 0.812000; val_acc: 0.593000
# (Iteration 21001 / 24500) loss: 1.094973
# (Epoch 43 / 50) train acc: 0.831000; val_acc: 0.593000
# (Iteration 21501 / 24500) loss: 1.018734
# (Epoch 44 / 50) train acc: 0.840000; val_acc: 0.592000
# (Iteration 22001 / 24500) loss: 0.920751
# (Epoch 45 / 50) train acc: 0.824000; val_acc: 0.589000
# (Iteration 22501 / 24500) loss: 0.921983
# (Epoch 46 / 50) train acc: 0.803000; val_acc: 0.582000
# (Iteration 23001 / 24500) loss: 1.031024
# (Epoch 47 / 50) train acc: 0.816000; val_acc: 0.591000
# (Iteration 23501 / 24500) loss: 0.928376
# (Epoch 48 / 50) train acc: 0.830000; val_acc: 0.590000
# (Iteration 24001 / 24500) loss: 0.991915
# (Epoch 49 / 50) train acc: 0.823000; val_acc: 0.590000
# (Epoch 50 / 50) train acc: 0.824000; val_acc: 0.590000

# %%
# ================================================================ #
# YOUR CODE HERE:
#   Implement a FC-net that achieves at least 60% validation accuracy
#   on CIFAR-10.
# ================================================================ #
learning_rate = 3.1e-4
weight_scale = 2.5e-2 #1e-5
model = FullyConnectedNet([600, 500, 400, 300, 200, 100],
                weight_scale=weight_scale, dtype=np.float64, dropout=0.25, use_batchnorm=True, reg=1e-2)
solver = Solver(model, data,
                print_every=500, num_epochs=34, batch_size=128,
                update_rule='adam',
                optim_config={
                  'learning_rate': learning_rate,
                },
                lr_decay=0.9
         )

solver.train()
# ================================================================ #
# END YOUR CODE HERE
# ================================================================ #
# Out:
# (Iteration 1 / 12988) loss: 10.483221
# (Epoch 0 / 34) train acc: 0.112000; val_acc: 0.102000
# (Epoch 1 / 34) train acc: 0.463000; val_acc: 0.439000
# (Iteration 501 / 12988) loss: 3.326658
# (Epoch 2 / 34) train acc: 0.467000; val_acc: 0.456000
# (Iteration 1001 / 12988) loss: 2.397130
# (Epoch 3 / 34) train acc: 0.477000; val_acc: 0.464000
# (Iteration 1501 / 12988) loss: 2.148057
# (Epoch 4 / 34) train acc: 0.510000; val_acc: 0.491000
# (Epoch 5 / 34) train acc: 0.511000; val_acc: 0.505000
# (Iteration 2001 / 12988) loss: 1.906599
# (Epoch 6 / 34) train acc: 0.540000; val_acc: 0.519000
# (Iteration 2501 / 12988) loss: 1.837982
# (Epoch 7 / 34) train acc: 0.559000; val_acc: 0.518000
# (Iteration 3001 / 12988) loss: 1.774247
# (Epoch 8 / 34) train acc: 0.574000; val_acc: 0.496000
# (Epoch 9 / 34) train acc: 0.574000; val_acc: 0.514000
# (Iteration 3501 / 12988) loss: 1.718714
# (Epoch 10 / 34) train acc: 0.563000; val_acc: 0.537000
# (Iteration 4001 / 12988) loss: 1.667887
# (Epoch 11 / 34) train acc: 0.589000; val_acc: 0.544000
# (Iteration 4501 / 12988) loss: 1.710234
# (Epoch 12 / 34) train acc: 0.583000; val_acc: 0.536000
# (Epoch 13 / 34) train acc: 0.588000; val_acc: 0.551000
# (Iteration 5001 / 12988) loss: 1.482404
# (Epoch 14 / 34) train acc: 0.616000; val_acc: 0.556000
# (Iteration 5501 / 12988) loss: 1.489951
# (Epoch 15 / 34) train acc: 0.610000; val_acc: 0.553000
# (Iteration 6001 / 12988) loss: 1.275014
# (Epoch 16 / 34) train acc: 0.644000; val_acc: 0.553000
# (Epoch 17 / 34) train acc: 0.642000; val_acc: 0.571000
# (Iteration 6501 / 12988) loss: 1.377364
# (Epoch 18 / 34) train acc: 0.676000; val_acc: 0.569000
# (Iteration 7001 / 12988) loss: 1.266566
# (Epoch 19 / 34) train acc: 0.671000; val_acc: 0.563000
# (Iteration 7501 / 12988) loss: 1.362772
# (Epoch 20 / 34) train acc: 0.688000; val_acc: 0.572000
# (Iteration 8001 / 12988) loss: 1.256650
# (Epoch 21 / 34) train acc: 0.686000; val_acc: 0.568000
# (Epoch 22 / 34) train acc: 0.716000; val_acc: 0.597000
# (Iteration 8501 / 12988) loss: 1.122761
# (Epoch 23 / 34) train acc: 0.738000; val_acc: 0.588000
# (Iteration 9001 / 12988) loss: 1.347743
# (Epoch 24 / 34) train acc: 0.714000; val_acc: 0.594000
# (Iteration 9501 / 12988) loss: 1.243068
# (Epoch 25 / 34) train acc: 0.720000; val_acc: 0.594000
# (Epoch 26 / 34) train acc: 0.721000; val_acc: 0.595000
# (Iteration 10001 / 12988) loss: 1.038406
# (Epoch 27 / 34) train acc: 0.735000; val_acc: 0.603000
# (Iteration 10501 / 12988) loss: 0.980343
# (Epoch 28 / 34) train acc: 0.758000; val_acc: 0.606000
# (Iteration 11001 / 12988) loss: 0.950109
# (Epoch 29 / 34) train acc: 0.765000; val_acc: 0.607000
# (Epoch 30 / 34) train acc: 0.772000; val_acc: 0.608000
# (Iteration 11501 / 12988) loss: 1.032920
# (Epoch 31 / 34) train acc: 0.795000; val_acc: 0.596000
# (Iteration 12001 / 12988) loss: 1.021529
# (Epoch 32 / 34) train acc: 0.791000; val_acc: 0.601000
# (Iteration 12501 / 12988) loss: 0.917924
# (Epoch 33 / 34) train acc: 0.775000; val_acc: 0.606000
# (Epoch 34 / 34) train acc: 0.777000; val_acc: 0.594000

# %%
# ================================================================ #
# YOUR CODE HERE:
#   Implement a FC-net that achieves at least 60% validation accuracy
#   on CIFAR-10.
# ================================================================ #
learning_rate = 3.1e-4
weight_scale = 2.5e-2 #1e-5
model = FullyConnectedNet([600, 500, 400, 300, 200, 100],
                weight_scale=weight_scale, dtype=np.float64, dropout=0.25, use_batchnorm=True, reg=1e-2)
solver = Solver(model, data,
                print_every=500, num_epochs=40, batch_size=128,
                update_rule='adam',
                optim_config={
                  'learning_rate': learning_rate,
                },
                lr_decay=0.9
         )

solver.train()
# ================================================================ #
# END YOUR CODE HERE
# ================================================================ #
# Out:
# (Iteration 1 / 15280) loss: 10.462556
# (Epoch 0 / 40) train acc: 0.117000; val_acc: 0.107000
# (Epoch 1 / 40) train acc: 0.448000; val_acc: 0.435000
# (Iteration 501 / 15280) loss: 3.443546
# (Epoch 2 / 40) train acc: 0.453000; val_acc: 0.461000
# (Iteration 1001 / 15280) loss: 2.252969
# (Epoch 3 / 40) train acc: 0.470000; val_acc: 0.467000
# (Iteration 1501 / 15280) loss: 2.037425
# (Epoch 4 / 40) train acc: 0.482000; val_acc: 0.487000
# (Epoch 5 / 40) train acc: 0.471000; val_acc: 0.498000
# (Iteration 2001 / 15280) loss: 1.895577
# (Epoch 6 / 40) train acc: 0.512000; val_acc: 0.494000
# (Iteration 2501 / 15280) loss: 1.788871
# (Epoch 7 / 40) train acc: 0.523000; val_acc: 0.506000
# (Iteration 3001 / 15280) loss: 1.674057
# (Epoch 8 / 40) train acc: 0.552000; val_acc: 0.515000
# (Epoch 9 / 40) train acc: 0.578000; val_acc: 0.530000
# (Iteration 3501 / 15280) loss: 1.726661
# (Epoch 10 / 40) train acc: 0.547000; val_acc: 0.526000
# (Iteration 4001 / 15280) loss: 1.487881
# (Epoch 11 / 40) train acc: 0.563000; val_acc: 0.525000
# (Iteration 4501 / 15280) loss: 1.281820
# (Epoch 12 / 40) train acc: 0.607000; val_acc: 0.526000
# (Epoch 13 / 40) train acc: 0.637000; val_acc: 0.549000
# (Iteration 5001 / 15280) loss: 1.487983
# (Epoch 14 / 40) train acc: 0.640000; val_acc: 0.552000
# (Iteration 5501 / 15280) loss: 1.521143
# (Epoch 15 / 40) train acc: 0.595000; val_acc: 0.561000
# (Iteration 6001 / 15280) loss: 1.511645
# (Epoch 16 / 40) train acc: 0.655000; val_acc: 0.565000
# (Epoch 17 / 40) train acc: 0.650000; val_acc: 0.543000
# (Iteration 6501 / 15280) loss: 1.403334
# (Epoch 18 / 40) train acc: 0.669000; val_acc: 0.578000
# (Iteration 7001 / 15280) loss: 1.445388
# (Epoch 19 / 40) train acc: 0.710000; val_acc: 0.583000
# (Iteration 7501 / 15280) loss: 1.196780
# (Epoch 20 / 40) train acc: 0.689000; val_acc: 0.584000
# (Iteration 8001 / 15280) loss: 1.322549
# (Epoch 21 / 40) train acc: 0.690000; val_acc: 0.562000
# (Epoch 22 / 40) train acc: 0.684000; val_acc: 0.578000
# (Iteration 8501 / 15280) loss: 1.134661
# (Epoch 23 / 40) train acc: 0.714000; val_acc: 0.580000
# (Iteration 9001 / 15280) loss: 1.266737
# (Epoch 24 / 40) train acc: 0.737000; val_acc: 0.580000
# (Iteration 9501 / 15280) loss: 1.267012
# (Epoch 25 / 40) train acc: 0.735000; val_acc: 0.588000
# (Epoch 26 / 40) train acc: 0.729000; val_acc: 0.590000
# (Iteration 10001 / 15280) loss: 1.137546
# (Epoch 27 / 40) train acc: 0.745000; val_acc: 0.578000
# (Iteration 10501 / 15280) loss: 1.028945
# (Epoch 28 / 40) train acc: 0.752000; val_acc: 0.567000
# (Iteration 11001 / 15280) loss: 1.077828
# (Epoch 29 / 40) train acc: 0.761000; val_acc: 0.579000
# (Epoch 30 / 40) train acc: 0.767000; val_acc: 0.582000
# (Iteration 11501 / 15280) loss: 1.114092
# (Epoch 31 / 40) train acc: 0.777000; val_acc: 0.585000
# (Iteration 12001 / 15280) loss: 1.171170
# (Epoch 32 / 40) train acc: 0.789000; val_acc: 0.571000
# (Iteration 12501 / 15280) loss: 0.956674
# (Epoch 33 / 40) train acc: 0.785000; val_acc: 0.582000
# (Epoch 34 / 40) train acc: 0.812000; val_acc: 0.598000
# (Iteration 13001 / 15280) loss: 1.063465
# (Epoch 35 / 40) train acc: 0.805000; val_acc: 0.586000
# (Iteration 13501 / 15280) loss: 0.967363
# (Epoch 36 / 40) train acc: 0.821000; val_acc: 0.593000
# (Iteration 14001 / 15280) loss: 1.058341
# (Epoch 37 / 40) train acc: 0.817000; val_acc: 0.588000
# (Iteration 14501 / 15280) loss: 1.066644
# (Epoch 38 / 40) train acc: 0.800000; val_acc: 0.585000
# (Epoch 39 / 40) train acc: 0.800000; val_acc: 0.589000
# (Iteration 15001 / 15280) loss: 0.949070
# (Epoch 40 / 40) train acc: 0.790000; val_acc: 0.573000

# %%
Validation Accuracy of ~60% achived in earlie Epochs.
